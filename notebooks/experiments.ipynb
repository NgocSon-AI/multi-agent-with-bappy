# %%
from langchain.tools import BaseTool
# Out:
# /home/ngocson/Sun/AI-Agent-Course-With-Bappy-Youtuber/multi-agent-with-bappy/.venv/lib/python3.11/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.7.0) or chardet (7.4.3)/charset_normalizer (3.4.7) doesn't match a supported version!
#   warnings.warn(
